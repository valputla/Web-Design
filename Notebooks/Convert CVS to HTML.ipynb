# %%
import pandas as pd
weather_df = pd.read_csv("/Users/lindseyvalput/Desktop/Web-Design/Notebooks/weather.csv")

# %%
weather_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        rikitea -23.1203 -134.9692     79.12        74           0
# 1    nizhneyansk   0.0000    0.0000      0.00         0           0
# 2       karratha -20.7377  116.8463     89.04        27           0
# 3         baglan  36.1307   68.7083     76.50        33         100
# 4    tuktoyaktuk  69.4541 -133.0374      3.20        66          20
# ..           ...      ...       ...       ...       ...         ...
# 605        metro  -5.1131  105.3067     83.95        67          80
# 606   sokolskoye  57.1412   43.1589     38.61        99         100
# 607     asadabad  34.7824   48.1185     40.95        40          39
# 608    maromitsa  59.8683   48.0123     36.61        99         100
# 609   betare oya   5.6000   14.0833     70.74        85         100
#
#      Wind Speed Country        Date
# 0         17.52      PF  1649640668
# 1          0.00       0           0
# 2          8.70      AU  1649640668
# ...

# %%
weather_data = pd.DataFrame.to_html

# %%
html = weather_df.to_html()
  
# write html to file
text_file = open("index.html", "w")
text_file.write(html)
text_file.close()
